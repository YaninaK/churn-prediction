# %% [markdown]
# <a href="https://colab.research.google.com/github/YaninaK/churn-prediction/blob/main/notebooks/04_Inference_results_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Прогнозирование оттока клиентов
# ## Анализ результатов инференса нейросетевой модели.
#
# ## [EDA и отбор признаков](https://github.com/YaninaK/churn-prediction/blob/main/notebooks/01_EDA_and_Feature_selection.ipynb)
#
# ## [Базовая нейросетевая модель](https://github.com/YaninaK/churn-prediction/blob/main/notebooks/02_Baseline_model_NN.ipynb)
#
# ## [Конвейер для инференса нейросетевой модели](https://github.com/YaninaK/churn-prediction/blob/main/notebooks/03_Inference_pipeline_nn.ipynb)
#
# [Ссылка на данные](https://drive.google.com/file/d/1TAVECAfnel9lPfcpfel6qXhZSW2yNqdX/view?usp=sharing)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/YaninaK/churn-prediction.git -q

# %%
# %cd churn-prediction
# Out:
# /content/churn-prediction

# %%
import sys
import os

sys.path.append(os.getcwd())
sys.path.append(os.path.join(os.getcwd(), "src", "churn_prediction"))

# %%
import logging
import pandas as pd
import numpy as np
import easydict

from data.make_dataset import load_data
from data.validation import train_test_data_split

from models.inference_tools import preprocessing_pipeline
from models.serialize import load

from models.utilities import (
    get_initial_bias_and_class_weight,
    plot_loss,
    plot_metrics,
    plot_cm,
    plot_roc,
    plot_prc,
    plot_lift,
)

import matplotlib.pyplot as plt

# %%
PATH = '/content/drive/MyDrive/ML_projects/06_Churn_prediction/'

# %%
ID = 'customerid'
TARGET_NAME = 'churn'

# %% [markdown]
# ## 1. Загрузка модели

# %%
lstm_model = load('LSTM_emb_model_v1', PATH + 'models/')

# %% [markdown]
# ## 2. Загрузка и подготовка данных

# %%
data = load_data(PATH)
_, data_test = train_test_data_split(data)
test_features, test_labels = preprocessing_pipeline(data_test, PATH)

# %% [markdown]
# ## 3. Инференс

# %%
predictions = lstm_model.predict(test_features)
# Out:
# 59/59 [==============================] - 1s 2ms/step

# %%
results = data_test.groupby(ID, as_index=False)[TARGET_NAME ].max()
results['predictions'] = predictions
results = results.sort_values(by='predictions', ascending=False).set_index(ID)
results['y_pred'] = (
    (results['predictions'] >= 0.5)
    .where(results['predictions'] < 0.5, True)
    .astype(int)
)
results
# Out:
#             churn   predictions  y_pred
# customerid
# 3466            0  9.964615e-01       1
# 4052            1  9.913965e-01       1
# 3494            1  9.887042e-01       1
# 3601            0  9.867486e-01       1
# 7149            1  9.844918e-01       1
# ...           ...           ...     ...
# 4678            0  3.952400e-11       0
# 4140            0  1.064870e-11       0
# 2407            0  5.623193e-12       0
# 7387            0  2.812500e-13       0
# 7421            0  2.760575e-13       0
#
# [1867 rows x 3 columns]

# %% [markdown]
# ## 4. False Positive

# %%
fp = results[(results['y_pred'] == 1) & (results[TARGET_NAME ] == 0)].index.tolist()
df_fp = (
    data_test[data_test[ID].isin(fp)].groupby(ID).first()
    .join(results[['predictions']], how='left')
    .sort_values(by='predictions', ascending=False)
)
df_fp.head(2)
# Out:
#             age  annualincome  calldroprate  callfailurerate  callingnum  \
# customerid
# 3466         48         64938          0.00             0.01  4251038772
# 3601         75         55291          0.01             0.03  4251036245
#
#            customersuspended               education  gender homeowner  \
# customerid
# 3466                     Yes  Bachelor or equivalent  Female       Yes
# 3601                     Yes  Bachelor or equivalent  Female        No
#
#            maritalstatus  ...  unpaidbalance usesinternetservice  \
# customerid                ...
# 3466              Single  ...            228                  No
# 3601             Married  ...            231                  No
#
#             usesvoiceservice  percentagecalloutsidenetwork  totalcallduration  \
# customerid
# 3466                      No                          0.92               1047
# 3601                      No                          0.90               2646
#
#            avgcallduration  churn  year  month  predictions
# customerid
# 3466                   261      0  2015      1     0.996462
# 3601                   661      0  2015      1     0.986749
#
# [2 rows x 29 columns]

# %%
df_fp['predictions_bins'] = pd.cut(df_fp['predictions'], 10)

df_fp.groupby('predictions_bins').agg(
      id_count = ("callingnum", "count"),
      age_mean=("age", "mean"),
      numberofcomplaints_mean=("numberofcomplaints", "mean"),
      callfailurerate_mean=("callfailurerate", "mean"),

      female_fraction=("gender", lambda x: x.value_counts(normalize=True)["Female"]),
      education_hs=("education", lambda x: x.value_counts(normalize=True)["High School or below"]),
      single_frac=("maritalstatus", lambda x: x.value_counts(normalize=True)["Single"]),
      homeowner_frac=("homeowner", lambda x: x.value_counts(normalize=True)["Yes"]),
      customersuspended_frac=("customersuspended", lambda x: x.value_counts(normalize=True)["Yes"]),
      not_usesinternetservice_frac=("usesinternetservice", lambda x: x.value_counts(normalize=True)["No"]),
      not_usesvoiceservice_frac=("usesvoiceservice", lambda x: x.value_counts(normalize=True)["No"]),

      unpaidbalance_mean=("unpaidbalance", "mean"),

).sort_index(ascending=False)
# Out:
#                   id_count   age_mean  numberofcomplaints_mean  \
# predictions_bins
# (0.947, 0.996]          11  54.272727                 2.636364
# (0.897, 0.947]          12  43.833333                 1.583333
# (0.848, 0.897]          28  42.500000                 1.964286
# (0.798, 0.848]          44  36.477273                 1.704545
# (0.748, 0.798]          56  39.267857                 1.732143
# (0.699, 0.748]          84  36.142857                 1.833333
# (0.649, 0.699]          75  33.720000                 1.426667
# (0.6, 0.649]            84  38.250000                 1.857143
# (0.55, 0.6]             85  36.294118                 1.800000
# (0.5, 0.55]             84  38.595238                 1.761905
#
#                   callfailurerate_mean  female_fraction  education_hs  \
# predictions_bins
# (0.947, 0.996]                0.020909         0.818182      0.363636
# (0.897, 0.947]                0.013333         0.833333      0.250000
# (0.848, 0.897]                0.016429         0.357143      0.535714
# (0.798, 0.848]                0.016591         0.522727      0.568182
# (0.748, 0.798]                0.014643         0.607143      0.500000
# (0.699, 0.748]                0.015238         0.523810      0.476190
# (0.649, 0.699]                0.014933         0.573333      0.586667
# (0.6, 0.649]                  0.015952         0.511905      0.535714
# (0.55, 0.6]                   0.015176         0.517647      0.517647
# (0.5, 0.55]                   0.016310         0.416667      0.559524
#
#                   single_frac  homeowner_frac  customersuspended_frac  \
# predictions_bins
# (0.947, 0.996]       0.818182        0.454545                1.000000
# (0.897, 0.947]       0.500000        0.583333                1.000000
# (0.848, 0.897]       0.464286        0.642857                0.964286
# (0.798, 0.848]       0.409091        0.681818                0.954545
# (0.748, 0.798]       0.500000        0.803571                1.000000
# (0.699, 0.748]       0.511905        0.833333                0.976190
# (0.649, 0.699]       0.573333        0.866667                0.973333
# (0.6, 0.649]         0.571429        0.821429                0.988095
# (0.55, 0.6]          0.552941        0.694118                1.000000
# (0.5, 0.55]          0.476190        0.845238                0.976190
#
#                   not_usesinternetservice_frac  not_usesvoiceservice_frac  \
# predictions_bins
# (0.947, 0.996]                        0.818182                   0.909091
# (0.897, 0.947]                        0.916667                   0.833333
# (0.848, 0.897]                        0.964286                   0.892857
# (0.798, 0.848]                        1.000000                   0.909091
# (0.748, 0.798]                        0.964286                   0.839286
# (0.699, 0.748]                        0.964286                   0.916667
# (0.649, 0.699]                        0.960000                   0.946667
# (0.6, 0.649]                          0.952381                   0.940476
# (0.55, 0.6]                           0.988235                   0.964706
# (0.5, 0.55]                           0.976190                   0.892857
#
#                   unpaidbalance_mean
# predictions_bins
# (0.947, 0.996]            153.909091
# (0.897, 0.947]            103.583333
# (0.848, 0.897]            122.178571
# (0.798, 0.848]            143.772727
# (0.748, 0.798]            142.821429
# (0.699, 0.748]            120.583333
# (0.649, 0.699]            128.120000
# (0.6, 0.649]              144.035714
# (0.55, 0.6]               150.694118
# (0.5, 0.55]               134.904762

# %% [markdown]
# * Чаще всего модель ошибочно классифицирует как отток женщин старше 43 лет, с numberofcomplaints больше 2, callfailurerate 0.02 и выше.

# %% [markdown]
# ## 5. False Negative

# %%
fn = results[(results['y_pred'] == 0) & (results[TARGET_NAME ] == 1)].index.tolist()

df_fn = (
    data_test[data_test[ID].isin(fn)].groupby(ID).first()
    .join(results[['predictions']], how='left')
    .sort_values(by='predictions')
)
df_fp.head(2)
# Out:
#             age  annualincome  calldroprate  callfailurerate  callingnum  \
# customerid
# 3466         48         64938          0.00             0.01  4251038772
# 3601         75         55291          0.01             0.03  4251036245
#
#            customersuspended               education  gender homeowner  \
# customerid
# 3466                     Yes  Bachelor or equivalent  Female       Yes
# 3601                     Yes  Bachelor or equivalent  Female        No
#
#            maritalstatus  ...  usesinternetservice usesvoiceservice  \
# customerid                ...
# 3466              Single  ...                   No               No
# 3601             Married  ...                   No               No
#
#             percentagecalloutsidenetwork  totalcallduration  avgcallduration  \
# customerid
# 3466                                0.92               1047              261
# 3601                                0.90               2646              661
#
#            churn  year month  predictions  predictions_bins
# customerid
# 3466           0  2015     1     0.996462    (0.947, 0.996]
# 3601           0  2015     1     0.986749    (0.947, 0.996]
#
# [2 rows x 30 columns]

# %%
df_fn['predictions_bins'] = pd.cut(df_fn['predictions'], 4)

df_fn.groupby('predictions_bins').agg(
      id_count = ("callingnum", "count"),
      age_mean=("age", "mean"),
      numberofcomplaints_mean=("numberofcomplaints", "mean"),
      callfailurerate_mean=("callfailurerate", "mean"),

      female_fraction=("gender", lambda x: x.value_counts(normalize=True)["Female"]),
      education_hs=("education", lambda x: x.value_counts(normalize=True)["High School or below"]),
      single_frac=("maritalstatus", lambda x: x.value_counts(normalize=True)["Single"]),
      homeowner_frac=("homeowner", lambda x: x.value_counts(normalize=True)["Yes"]),
      customersuspended_frac=("customersuspended", lambda x: x.value_counts(normalize=True)["Yes"]),
      not_usesinternetservice_frac=("usesinternetservice", lambda x: x.value_counts(normalize=True)["No"]),
      not_usesvoiceservice_frac=("usesvoiceservice", lambda x: x.value_counts(normalize=True)["No"]),

      unpaidbalance_mean=("unpaidbalance", "mean"),

).sort_index()
# Out:
#                   id_count   age_mean  numberofcomplaints_mean  \
# predictions_bins
# (0.222, 0.291]           7  36.857143                 2.142857
# (0.291, 0.361]          12  40.500000                 1.166667
# (0.361, 0.43]            7  28.285714                 2.142857
# (0.43, 0.499]           13  41.230769                 1.615385
#
#                   callfailurerate_mean  female_fraction  education_hs  \
# predictions_bins
# (0.222, 0.291]                0.020000         0.714286      0.571429
# (0.291, 0.361]                0.016667         0.583333      0.666667
# (0.361, 0.43]                 0.010000         0.285714      0.714286
# (0.43, 0.499]                 0.018462         0.615385      0.384615
#
#                   single_frac  homeowner_frac  customersuspended_frac  \
# predictions_bins
# (0.222, 0.291]       0.714286        1.000000                     1.0
# (0.291, 0.361]       0.333333        0.833333                     1.0
# (0.361, 0.43]        0.285714        0.714286                     1.0
# (0.43, 0.499]        0.461538        0.692308                     1.0
#
#                   not_usesinternetservice_frac  not_usesvoiceservice_frac  \
# predictions_bins
# (0.222, 0.291]                        1.000000                   0.857143
# (0.291, 0.361]                        1.000000                   1.000000
# (0.361, 0.43]                         1.000000                   0.857143
# (0.43, 0.499]                         0.923077                   1.000000
#
#                   unpaidbalance_mean
# predictions_bins
# (0.222, 0.291]            135.571429
# (0.291, 0.361]            145.416667
# (0.361, 0.43]              93.285714
# (0.43, 0.499]             162.769231

# %% [markdown]
# * Модель затрудняется правильно определить отток у клентов моложе 40 лет, даже если numberofcomplaints больше 2 или callfailurerate_mean равна 0.02.
